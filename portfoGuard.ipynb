# %%
from matplotlib import pyplot as plt
from show_portfolio import *
import tabulate
from IPython.display import display, HTML
from datetime import timedelta, datetime

# %%
# trades = read_trades()
# trades = read_trades(filter=["BTC-USD", "IWDA.AS","VUAA.DE"])
trades = read_trades(filter=["BTC-USD"])
calculate_columns(trades)
# Out:
# WARNING: ussing older currency rate for USD. 2024-05-16 instead 2024-05-17
# Exchange rate called
# WARNING: ussing older currency rate for EUR. 2024-05-16 instead 2024-05-17
# Exchange rate called

# %% [markdown]
# # Trades

# %% [markdown]
# ### Akcie

# %%
tabulate.tabulate(
    trades[trades.type == "Akcie"].sort_values("date").reset_index(drop=True),
    tablefmt="html",
    headers="keys",
)
# Out:
# '<table>\n<thead>\n<tr><th style="text-align: right;">  </th><th>name           </th><th>ticker  </th><th>type  </th><th>tradeType  </th><th>date      </th><th style="text-align: right;">   units</th><th style="text-align: right;">  price</th><th style="text-align: right;">  fees</th><th>currency  </th><th style="text-align: right;">  note</th><th style="text-align: right;">  total_price</th><th style="text-align: right;">  current_price</th><th style="text-align: right;">  current_total_price</th><th style="text-align: right;">     profit</th><th style="text-align: right;">   change</th></tr>\n</thead>\n<tbody>\n<tr><td style="text-align: right;"> 0</td><td>Moneta         </td><td>MONET.PR</td><td>Akcie </td><td>Buy        </td><td>2022-04-27</td><td style="text-align: right;">106     </td><td style="text-align: right;">  94   </td><td style="text-align: right;">     0</td><td>CZK       </td><td style="text-align: right;">   nan</td><td style="text-align: right;">     9964    </td><td style="text-align: right;">         96.4  </td><td style="text-align: right;">            10218.4  </td><td style="text-align: right;">  254.4    </td><td style="text-align: right;">  2.55319</td></tr>\n<tr><td style="text-align: right;"> 1</td><td>Moneta         </td><td>MONET.PR</td><td>Akcie </td><td>Buy        </td><td>2022-04-28</td><td style="text-align: right;">  9     </td><td style="text-align: right;">  93.9 </td><td style="text-align: right;">     0</td><td>CZK       </td><td style="text-align: right;">   nan</td><td style="text-align: right;">      845.1  </td><td style="text-align: right;">         96.4  </td><td style="text-align: right;">              867.6  </td><td style="text-align: right;">   22.5    </td><td style="text-align: right;">  2.66241</td></tr>\n<tr><td style="text-align: right;"> 2</td><td>FB             </td><td>META    </td><td>Akcie </td><td>Buy        </td><td>2022-06-21</td><td style="text-align: right;">  2     </td><td style="text-align: right;"> 156.87</td><td style="text-align: right;">     0</td><td>USD       </td><td style="text-align: right;">   nan</td><td style="text-align: right;">     7342.41 </td><td style="text-align: right;">      10761.1  </td><td style="text-align: right;">            21522.3  </td><td style="text-align: right;">14179.8    </td><td style="text-align: right;">193.123  </td></tr>\n<tr><td style="text-align: right;"> 3</td><td>Palantir       </td><td>PLTR    </td><td>Akcie </td><td>Buy        </td><td>2022-08-04</td><td style="text-align: right;"> 11     </td><td style="text-align: right;">  11.32</td><td style="text-align: right;">     0</td><td>USD       </td><td style="text-align: right;">   nan</td><td style="text-align: right;">     3015.95 </td><td style="text-align: right;">        492.315</td><td style="text-align: right;">             5415.47 </td><td style="text-align: right;"> 2399.52   </td><td style="text-align: right;"> 79.561  </td></tr>\n<tr><td style="text-align: right;"> 4</td><td>CEZ            </td><td>CEZ.PR  </td><td>Akcie </td><td>Buy        </td><td>2022-10-27</td><td style="text-align: right;"> 12     </td><td style="text-align: right;"> 815   </td><td style="text-align: right;">     0</td><td>CZK       </td><td style="text-align: right;">   nan</td><td style="text-align: right;">     9780    </td><td style="text-align: right;">        923    </td><td style="text-align: right;">            11076    </td><td style="text-align: right;"> 1296      </td><td style="text-align: right;"> 13.2515 </td></tr>\n<tr><td style="text-align: right;"> 5</td><td>Komercni banka </td><td>KOMB.PR </td><td>Akcie </td><td>Buy        </td><td>2023-02-27</td><td style="text-align: right;"> 13     </td><td style="text-align: right;"> 749   </td><td style="text-align: right;">     0</td><td>CZK       </td><td style="text-align: right;">   nan</td><td style="text-align: right;">     9737    </td><td style="text-align: right;">        789.5  </td><td style="text-align: right;">       ...

# %% [markdown]
# ### ETF

# %%
tabulate.tabulate(
    trades[trades.type == "ETF"].sort_values("date").reset_index(drop=True),
    tablefmt="html",
    headers="keys",
)
# Out:
# '<table>\n<thead>\n<tr><th style="text-align: right;">  </th><th>name              </th><th>ticker  </th><th>type  </th><th>tradeType  </th><th>date      </th><th style="text-align: right;">  units</th><th style="text-align: right;">  price</th><th style="text-align: right;">  fees</th><th>currency  </th><th style="text-align: right;">  note</th><th style="text-align: right;">  total_price</th><th style="text-align: right;">  current_price</th><th style="text-align: right;">  current_total_price</th><th style="text-align: right;">    profit</th><th style="text-align: right;">   change</th></tr>\n</thead>\n<tbody>\n<tr><td style="text-align: right;"> 0</td><td>IShares Core World</td><td>IWDA.AS </td><td>ETF   </td><td>Buy        </td><td>2023-03-15</td><td style="text-align: right;"> 1     </td><td style="text-align: right;">69.755 </td><td style="text-align: right;">     0</td><td>EUR       </td><td style="text-align: right;">   nan</td><td style="text-align: right;">      1670.07</td><td style="text-align: right;">        2272.73</td><td style="text-align: right;">              2272.73</td><td style="text-align: right;"> 602.66   </td><td style="text-align: right;">36.0858  </td></tr>\n<tr><td style="text-align: right;"> 1</td><td>IShares Core World</td><td>IWDA.AS </td><td>ETF   </td><td>Buy        </td><td>2023-04-18</td><td style="text-align: right;"> 1     </td><td style="text-align: right;">73.085 </td><td style="text-align: right;">     0</td><td>EUR       </td><td style="text-align: right;">   nan</td><td style="text-align: right;">      1708.22</td><td style="text-align: right;">        2272.73</td><td style="text-align: right;">              2272.73</td><td style="text-align: right;"> 564.518  </td><td style="text-align: right;">33.0472  </td></tr>\n<tr><td style="text-align: right;"> 2</td><td>IShares Core World</td><td>IWDA.AS </td><td>ETF   </td><td>Buy        </td><td>2023-05-17</td><td style="text-align: right;"> 2     </td><td style="text-align: right;">73.59  </td><td style="text-align: right;">     1</td><td>EUR       </td><td style="text-align: right;">   nan</td><td style="text-align: right;">      3478.16</td><td style="text-align: right;">        2272.73</td><td style="text-align: right;">              4545.47</td><td style="text-align: right;">1067.31   </td><td style="text-align: right;">30.6861  </td></tr>\n<tr><td style="text-align: right;"> 3</td><td>IShares Core World</td><td>IWDA.AS </td><td>ETF   </td><td>Buy        </td><td>2023-08-04</td><td style="text-align: right;"> 3     </td><td style="text-align: right;">77.7   </td><td style="text-align: right;">     1</td><td>EUR       </td><td style="text-align: right;">   nan</td><td style="text-align: right;">      5655.01</td><td style="text-align: right;">        2272.73</td><td style="text-align: right;">              6818.2 </td><td style="text-align: right;">1163.2    </td><td style="text-align: right;">20.5693  </td></tr>\n<tr><td style="text-align: right;"> 4</td><td>IShares Core World</td><td>IWDA.AS </td><td>ETF   </td><td>Buy        </td><td>2023-09-26</td><td style="text-align: right;"> 2     </td><td style="text-align: right;">77.225 </td><td style="text-align: right;">     1</td><td>EUR       </td><td style="text-align: right;">   nan</td><td style="text-align: right;">      3770.28</td><td style="text-align: right;">        2272.73</td><td style="text-align: right;">              4545.47</td><td style="text-align: right;"> 775.189  </td><td style="text-align: right;">20.5605  </td></tr>\n<tr><td style="text-align: right;"> 5</td><td>IShares Core World</td><td>IWDA.AS </td><td>ETF   </td><td>Buy        </td><td>2023-12-05</td><td style="text-align: right;"> 3     </td><td style="text-align: right;">79.7   </td><td style="text-align: right;">     1</td><td>EUR       </td><td style="text-align: right;">   nan</td><td style="text-align: right;">      5826.63</td><td style="text-align: right;">        2272.73</td><td style="text-align: right; ...

# %% [markdown]
# ### Krypto

# %%
tabulate.tabulate(
    trades[trades.type == "Krypto"].sort_values("date").reset_index(drop=True),
    tablefmt="html",
    headers="keys",
)
# Out:
# '<table>\n<thead>\n<tr></tr>\n</thead>\n<tbody>\n</tbody>\n</table>'

# %% [markdown]
# # Investice

# %%
first_date = datetime.fromisoformat(trades["date"].sort_values().loc[0]).date()
today_date = datetime.now().date()
n_months = round((today_date-first_date).days/30)
total_invested_czk = trades["total_price"].sum()
print("Pocet mesicu od prvni investice:",n_months)
print("Celkem investovano:",f"{total_invested_czk:.2f}")
print("Prumerna investovana castka:",f"{total_invested_czk/n_months:.2f}")
# Out:
# Pocet mesicu od prvni investice: 25
# Celkem investovano: 365043.06
# Prumerna investovana castka: 14601.72

# %%
first_year = first_date.year
last_year = today_date.year
dates = []
for year in range(first_year,last_year+1):
    dates.extend([f"{str(year)[-2:]}/{x:0>2}" for x in range(1,13)])
values = [0]*len(dates)
all_trades_small = pd.DataFrame(index=dates,data=values,columns=["total_price"])

# %%
trades_small = trades.loc[:,["date","total_price"]]
trades_small["date"] = trades_small["date"].apply(lambda x: x.split("-")[0][-2:] + "/" + x.split("-")[1])
trades_small = trades_small.groupby("date").agg("sum")
for index,values in trades_small.iterrows():
	# print(index,values["total_price"])
	all_trades_small.loc[index] = values["total_price"]
# trades_small
all_trades_small.reset_index(names="date",inplace=True)

# %%
fig = px.bar(
    all_trades_small,
    x="date",
    y="total_price",
    title="Historical investments",
    template="plotly_dark",
    width=1200,
    height=800,
)

# showing the plot
fig.show()

# %%
all_trades_small[["year","month"]] = all_trades_small["date"].str.split("/",expand=True)
pivot_trades = all_trades_small.pivot(index="year",columns="month",values="total_price")
pivot_trades["celkem"] = pivot_trades.sum(axis=1)
pivot_trades
# Out:
# month            01            02            03            04           05  \
# year
# 22         0.000000      0.000000      0.000000  10809.100000      0.00000
# 23         0.000000   9737.000000   1670.074210  53040.369642  18031.15776
# 24     27754.990876  22960.336239  27373.322226  28489.499278  20078.39913
#
# month            06       07            08          09      10            11  \
# year
# 22      7342.408152      0.0   3015.949985     0.00000  9780.0      0.000000
# 23     28519.075367  16020.0  15804.380405  3770.27895     0.0  20357.278017
# 24         0.000000      0.0      0.000000     0.00000     0.0      0.000000
#
# month            12         celkem
# year
# 22         0.000000   30947.458137
# 23     40489.440335  207439.054686
# 24         0.000000  126656.547748

# %% [markdown]
# # Prehled

# %%
summary = get_summary(trades)

# %%
get_overview(summary)
# Out:
# 	<div style="display:flex; justify-content: space-between;">
#
# 		<div style="width: 350px; background-color:#f2f2f2; padding:20px; border-radius: 10px;">
# 			<h2>Celková hodnota portfolia</h2>
# 			<p style="font-size:18px; color:#008080;">430622.62 Kc</p>
# 		</div>
#
# 		<div style="width: 350px; background-color:#f2f2f2; padding:20px; border-radius: 10px;">
# 			<h2>Investováno</h2>
# 			<p style="font-size:18px; color:#008080;">365043.06 Kc</p>
# 		</div>
#
# 		<div style="width: 350px; background-color:#f2f2f2; padding:20px; border-radius: 10px;">
# 			<h2>Celkové nerealizované zhodnocení</h2>
# 			<p style="font-size:18px; color:#008080;">65579.56 Kc</p>
# 			<p style="font-size:15px; color:#008080;">17.96 % z investované částky</p>
# 		</div>
# 	</d

# %%
tabulate.tabulate(
    summary.reset_index(drop=True),
    tablefmt="html",
    headers="keys",
)
# Out:
# '<table>\n<thead>\n<tr><th style="text-align: right;">  </th><th>ticker  </th><th style="text-align: right;">   units</th><th style="text-align: right;">  total_price</th><th>currency  </th><th>type  </th><th style="text-align: right;">  mean_price</th><th style="text-align: right;">  current_price</th><th style="text-align: right;">  current_total_price</th><th style="text-align: right;">   profit</th><th style="text-align: right;">   change</th></tr>\n</thead>\n<tbody>\n<tr><td style="text-align: right;"> 0</td><td>BAC     </td><td style="text-align: right;"> 15     </td><td style="text-align: right;">      9350.95</td><td>USD       </td><td>Akcie </td><td style="text-align: right;">    623.397 </td><td style="text-align: right;">        891.853</td><td style="text-align: right;">             13377.8 </td><td style="text-align: right;"> 4026.84 </td><td style="text-align: right;"> 43.0634 </td></tr>\n<tr><td style="text-align: right;"> 1</td><td>CEZ.PR  </td><td style="text-align: right;"> 92     </td><td style="text-align: right;">     79368.5 </td><td>CZK       </td><td>Akcie </td><td style="text-align: right;">    862.701 </td><td style="text-align: right;">        923    </td><td style="text-align: right;">             84916   </td><td style="text-align: right;"> 5547.5  </td><td style="text-align: right;">  6.98955</td></tr>\n<tr><td style="text-align: right;"> 2</td><td>CRWD    </td><td style="text-align: right;">  3     </td><td style="text-align: right;">     10108.6 </td><td>USD       </td><td>Akcie </td><td style="text-align: right;">   3369.52  </td><td style="text-align: right;">       7710.14 </td><td style="text-align: right;">             23130.4 </td><td style="text-align: right;">13021.9  </td><td style="text-align: right;">128.82   </td></tr>\n<tr><td style="text-align: right;"> 3</td><td>GOOGL   </td><td style="text-align: right;">  5     </td><td style="text-align: right;">     11190.2 </td><td>USD       </td><td>Akcie </td><td style="text-align: right;">   2238.03  </td><td style="text-align: right;">       3960.81 </td><td style="text-align: right;">             19804   </td><td style="text-align: right;"> 8613.88 </td><td style="text-align: right;"> 76.9773 </td></tr>\n<tr><td style="text-align: right;"> 4</td><td>IWDA.AS </td><td style="text-align: right;"> 16     </td><td style="text-align: right;">     30771.4 </td><td>EUR       </td><td>ETF   </td><td style="text-align: right;">   1923.21  </td><td style="text-align: right;">       2272.73 </td><td style="text-align: right;">             36363.7 </td><td style="text-align: right;"> 5592.33 </td><td style="text-align: right;"> 18.1738 </td></tr>\n<tr><td style="text-align: right;"> 5</td><td>KOMB.PR </td><td style="text-align: right;"> 61     </td><td style="text-align: right;">     43816   </td><td>CZK       </td><td>Akcie </td><td style="text-align: right;">    718.295 </td><td style="text-align: right;">        789.5  </td><td style="text-align: right;">             48159.5 </td><td style="text-align: right;"> 4343.5  </td><td style="text-align: right;">  9.91305</td></tr>\n<tr><td style="text-align: right;"> 6</td><td>META    </td><td style="text-align: right;">  2     </td><td style="text-align: right;">      7342.41</td><td>USD       </td><td>Akcie </td><td style="text-align: right;">   3671.2   </td><td style="text-align: right;">      10761.1  </td><td style="text-align: right;">             21522.3 </td><td style="text-align: right;">14179.8  </td><td style="text-align: right;">193.123  </td></tr>\n<tr><td style="text-align: right;"> 7</td><td>MO      </td><td style="text-align: right;"> 30     </td><td style="text-align: right;">     27401.9 </td><td>USD       </td><td>Akcie </td><td style="text-align: right;">    913.395 </td><td style="text-align: right;">       1044.89 </td><td style="text-align: right;">             31346.7 </td><td style="text-align: right;"> 3944.88 </td><td style="text-align: right;"> 14.3964 </td></tr>\n<tr><td sty ...

# %%
show_portfolio_breakdown(summary)
show_portfolio_growth(summary)

# %% [markdown]
# # Casovy vyvoj

# %%
def get_units(ticker: str, date_to: str) -> float:
    return trades[(trades.ticker == ticker) & (trades.date < date_to)]["units"].sum()


def get_total_price(ticker: str, date_to: str) -> float:
    return trades[(trades.ticker == ticker) & (trades.date < date_to)]["total_price"].sum()

# %%
# Aktuální datum
current_date = datetime.now().date()
n_days = 550
# Vytvoření seznamu posledních třiceti dnů
last_thirty_days = [
    (current_date - timedelta(days=i)).strftime("%Y-%m-%d") for i in range(n_days)
]
safety_range = (current_date - timedelta(days=n_days + 10)).strftime("%Y-%m-%d")
last_thirty_days = sorted(last_thirty_days)
time_evol = pd.DataFrame(columns=["date", "ticker", "value","total_price"])
for ticker in summary["ticker"].unique():
    # for ticker in ["CEZ.PR"]:
    currency = summary[summary["ticker"] == ticker].iloc[0]["currency"]
    stock = yf.Ticker(ticker)
    history = stock.history(start=safety_range, end=last_thirty_days[-1])[
        "Close"
    ].reset_index()
    history["Date"] = history["Date"].dt.strftime("%Y-%m-%d")
    # print(history)
    for date in last_thirty_days:
        # print(date)
        if date in history["Date"].values:
            price = float(history[history["Date"] == date]["Close"])
            # print("Found:",price)
        else:
            price = history[history["Date"] < date].iloc[-1]["Close"]
            # print("Not found",price)
        time_evol.loc[len(time_evol)] = [date,ticker,price * get_exchange_rate(currency, date) * get_units(ticker, date), get_total_price(ticker,date)]
        # print(index, price, get_exchange_rate(currency, index))
# print(time_evol)
time_evol["gain"] = time_evol["value"]/time_evol["total_price"]*100-100
# Out:
# WARNING: ussing older currency rate for USD. 2024-05-10 instead 2024-05-12
# Exchange rate called
# WARNING: ussing older currency rate for EUR. 2024-05-10 instead 2024-05-12
# Exchange rate called

# %%
print(time_evol)
# Out:
#             date ticker         value   total_price      gain
# 0     2022-11-15    BAC      0.000000      0.000000       NaN
# 1     2022-11-16    BAC      0.000000      0.000000       NaN
# 2     2022-11-17    BAC      0.000000      0.000000       NaN
# 3     2022-11-18    BAC      0.000000      0.000000       NaN
# 4     2022-11-19    BAC      0.000000      0.000000       NaN
# ...          ...    ...           ...           ...       ...
# 8245  2024-05-13    WPC  39054.870453  41002.857495 -4.750857
# 8246  2024-05-14    WPC  39457.633758  41002.857495 -3.768576
# 8247  2024-05-15    WPC  39431.487682  41002.857495 -3.832342
# 8248  2024-05-16    WPC  39276.987064  41002.857495 -4.209147
# 8249  2024-05-17    WPC  39276.987064  41002.857495 -4.209147
#
# [8250 rows x 5 columns]

# %%
fig = px.line(
    time_evol,
    x="date",
    y="value",
    color="ticker",
    title="Time evolution",
    template="plotly_dark",
    width=1200,
    height=800,
)

# showing the plot
fig.show()

# %%
fig = px.line(
    time_evol,
    x="date",
    y="gain",
    color="ticker",
    title="Time evolution",
    template="plotly_dark",
    width=1200,
    height=800,
)

# showing the plot
fig.show()

# %%
print(time_evol)
# Out:
#             date ticker         value   total_price      gain
# 0     2022-11-15    BAC      0.000000      0.000000       NaN
# 1     2022-11-16    BAC      0.000000      0.000000       NaN
# 2     2022-11-17    BAC      0.000000      0.000000       NaN
# 3     2022-11-18    BAC      0.000000      0.000000       NaN
# 4     2022-11-19    BAC      0.000000      0.000000       NaN
# ...          ...    ...           ...           ...       ...
# 8245  2024-05-13    WPC  39054.870453  41002.857495 -4.750857
# 8246  2024-05-14    WPC  39457.633758  41002.857495 -3.768576
# 8247  2024-05-15    WPC  39431.487682  41002.857495 -3.832342
# 8248  2024-05-16    WPC  39276.987064  41002.857495 -4.209147
# 8249  2024-05-17    WPC  39276.987064  41002.857495 -4.209147
#
# [8250 rows x 5 columns]

# %%
time_evol_all = time_evol.groupby("date").agg({"value":"sum","total_price":"sum"}).reset_index()
time_evol_all["gainAbs"] = time_evol_all["value"] - time_evol_all["total_price"]
time_evol_all["gain"] = time_evol_all["value"]/time_evol_all["total_price"]*100-100
time_evol_all
# Out:
#            date          value    total_price       gainAbs       gain
# 0    2022-11-15   23047.627862   30947.458137  -7899.830275 -25.526588
# 1    2022-11-16   22551.099314   30947.458137  -8396.358822 -27.131013
# 2    2022-11-17   22432.379736   30947.458137  -8515.078401 -27.514629
# 3    2022-11-18   22470.415199   30947.458137  -8477.042938 -27.391726
# 4    2022-11-19   22470.415199   30947.458137  -8477.042938 -27.391726
# ..          ...            ...            ...           ...        ...
# 545  2024-05-13  427928.533077  365043.060571  62885.472506  17.226864
# 546  2024-05-14  429299.174260  365043.060571  64256.113689  17.602338
# 547  2024-05-15  433230.826985  365043.060571  68187.766414  18.679376
# 548  2024-05-16  430450.995004  365043.060571  65407.934433  17.917868
# 549  2024-05-17  430450.995004  365043.060571  65407.934433  17.917868
#
# [550 rows x 5 columns]

# %%
time_evol_all.columns[1:-1]
# Out:
# Index(['value', 'total_price', 'gainAbs'], dtype='object')

# %%
fig = px.line(
    time_evol_all,
    x="date",
    # y=["value","total_gain"],
    y=time_evol_all.columns[1:-2],
    title="Time evolution",
    template="plotly_dark",
    width=1200,
    height=800,
)

# showing the plot
fig.show()

# %%
fig = px.line(
    time_evol_all,
    x="date",
    y="gainAbs",
    title="Time evolution",
    template="plotly_dark",
    width=1200,
    height=800,
)

# showing the plot
fig.show()

# %%
fig = px.line(
    time_evol_all,
    x="date",
    y="gain",
    title="Time evolution",
    template="plotly_dark",
    width=1200,
    height=800,
)

# showing the plot
fig.show()

# %%
z = time_evol_all[time_evol_all.date == "2023-01-01"]
a = time_evol_all[time_evol_all.date == "2024-01-01"]
b = time_evol_all[time_evol_all.date == "2024-02-01"]
c = time_evol_all[time_evol_all.date == "2024-03-01"]
d = time_evol_all[time_evol_all.date == "2024-04-01"]
e = time_evol_all[time_evol_all.date == "2024-05-01"]

print((a["gainAbs"].iloc[0]-z["gainAbs"].iloc[0])/z["value"].iloc[0]*100)
print((b["gainAbs"].iloc[0]-a["gainAbs"].iloc[0])/a["value"].iloc[0]*100)
print((c["gainAbs"].iloc[0]-b["gainAbs"].iloc[0])/b["value"].iloc[0]*100)
print((d["gainAbs"].iloc[0]-c["gainAbs"].iloc[0])/c["value"].iloc[0]*100)
print((e["gainAbs"].iloc[0]-d["gainAbs"].iloc[0])/d["value"].iloc[0]*100)
print((e["gainAbs"].iloc[0]-a["gainAbs"].iloc[0])/a["value"].iloc[0]*100)
# Out:
# 143.27462308776506
# 3.449004285500848
# 2.81189219247947
# 3.3324530902047442
# 0.2533265250146403
# 11.213683800113014

# %%
# Aktuální datum
current_date = datetime.now().date()
n_days = 550
# Vytvoření seznamu posledních třiceti dnů
last_thirty_days = [
    (current_date - timedelta(days=i)).strftime("%Y-%m-%d") for i in range(n_days)
]
safety_range = (current_date - timedelta(days=n_days + 10)).strftime("%Y-%m-%d")
last_thirty_days = sorted(last_thirty_days)
time_evol = pd.DataFrame(columns=["date", "ticker", "valueUSD", "value"])
for ticker in ["^GSPC"]:
    # for ticker in ["CEZ.PR"]:
    currency = "USD"
    stock = yf.Ticker(ticker)
    history = stock.history(start=safety_range, end=last_thirty_days[-1])[
        "Close"
    ].reset_index()
    history["Date"] = history["Date"].dt.strftime("%Y-%m-%d")
    # print(history)
    for date in last_thirty_days:
        # print(date)
        if date in history["Date"].values:
            price = float(history[history["Date"] == date]["Close"])
            # print("Found:",price)
        else:
            price = history[history["Date"] < date].iloc[-1]["Close"]
            # print("Not found",price)
        time_evol.loc[len(time_evol)] = [date,ticker,price,price * get_exchange_rate(currency, date)]
        #time_evol.loc[len(time_evol)] = [date,ticker,price]
        # print(index, price, get_exchange_rate(currency, index))
# print(time_evol)

z = time_evol[time_evol.date == "2023-01-01"]
a = time_evol[time_evol.date == "2024-01-01"]
b = time_evol[time_evol.date == "2024-02-01"]
c = time_evol[time_evol.date == "2024-03-01"]
d = time_evol[time_evol.date == "2024-04-01"]
e = time_evol[time_evol.date == "2024-05-01"]

#print(z)
#print(a)
#print(b)
#print(c)
#print(d)

column = "valueUSD"
print((a[column].iloc[0]-z[column].iloc[0])/z[column].iloc[0]*100)
print((b[column].iloc[0]-a[column].iloc[0])/a[column].iloc[0]*100)
print((c[column].iloc[0]-b[column].iloc[0])/b[column].iloc[0]*100)
print((d[column].iloc[0]-c[column].iloc[0])/c[column].iloc[0]*100)
print((e[column].iloc[0]-d[column].iloc[0])/d[column].iloc[0]*100)
print((e[column].iloc[0]-a[column].iloc[0])/a[column].iloc[0]*100)
# Out:
# 24.2305007976299
# 2.8587991825246
# 4.706098611676874
# 2.076859612536761
# -4.2980504860632145
# 5.211088330665605

# %% [markdown]
# # Dividendy

# %%
dividends = get_dividends(trades)
tabulate.tabulate(
    dividends,
    tablefmt="html",
    headers="keys",
)
# Out:
# '<table>\n<thead>\n<tr><th style="text-align: right;">  </th><th>ticker  </th><th>date      </th><th style="text-align: right;">  year</th><th style="text-align: right;">  total_gain_czk</th><th>currency  </th></tr>\n</thead>\n<tbody>\n<tr><td style="text-align: right;"> 0</td><td>MONET.PR</td><td>2022-04-29</td><td style="text-align: right;">  2022</td><td style="text-align: right;">        805     </td><td>CZK       </td></tr>\n<tr><td style="text-align: right;"> 1</td><td>MONET.PR</td><td>2023-04-28</td><td style="text-align: right;">  2023</td><td style="text-align: right;">       2840     </td><td>CZK       </td></tr>\n<tr><td style="text-align: right;"> 2</td><td>MONET.PR</td><td>2024-04-26</td><td style="text-align: right;">  2024</td><td style="text-align: right;">       3195     </td><td>CZK       </td></tr>\n<tr><td style="text-align: right;"> 3</td><td>META    </td><td>2024-02-21</td><td style="text-align: right;">  2024</td><td style="text-align: right;">         23.4804</td><td>USD       </td></tr>\n<tr><td style="text-align: right;"> 4</td><td>CEZ.PR  </td><td>2023-06-29</td><td style="text-align: right;">  2023</td><td style="text-align: right;">       1740     </td><td>CZK       </td></tr>\n<tr><td style="text-align: right;"> 5</td><td>KOMB.PR </td><td>2023-04-28</td><td style="text-align: right;">  2023</td><td style="text-align: right;">       2356.38  </td><td>CZK       </td></tr>\n<tr><td style="text-align: right;"> 6</td><td>KOMB.PR </td><td>2024-05-03</td><td style="text-align: right;">  2024</td><td style="text-align: right;">       5042.26  </td><td>CZK       </td></tr>\n<tr><td style="text-align: right;"> 7</td><td>BAC     </td><td>2023-08-31</td><td style="text-align: right;">  2023</td><td style="text-align: right;">         79.7379</td><td>USD       </td></tr>\n<tr><td style="text-align: right;"> 8</td><td>BAC     </td><td>2023-11-30</td><td style="text-align: right;">  2023</td><td style="text-align: right;">         80.0029</td><td>USD       </td></tr>\n<tr><td style="text-align: right;"> 9</td><td>BAC     </td><td>2024-02-29</td><td style="text-align: right;">  2024</td><td style="text-align: right;">         84.3403</td><td>USD       </td></tr>\n<tr><td style="text-align: right;">10</td><td>WPC     </td><td>2023-06-29</td><td style="text-align: right;">  2023</td><td style="text-align: right;">        136.037 </td><td>USD       </td></tr>\n<tr><td style="text-align: right;">11</td><td>WPC     </td><td>2023-09-28</td><td style="text-align: right;">  2023</td><td style="text-align: right;">        315.432 </td><td>USD       </td></tr>\n<tr><td style="text-align: right;">12</td><td>WPC     </td><td>2023-12-28</td><td style="text-align: right;">  2023</td><td style="text-align: right;">        401.597 </td><td>USD       </td></tr>\n<tr><td style="text-align: right;">13</td><td>WPC     </td><td>2024-03-27</td><td style="text-align: right;">  2024</td><td style="text-align: right;">        425.222 </td><td>USD       </td></tr>\n<tr><td style="text-align: right;">14</td><td>MO      </td><td>2023-12-20</td><td style="text-align: right;">  2023</td><td style="text-align: right;">        219.73  </td><td>USD       </td></tr>\n<tr><td style="text-align: right;">15</td><td>MO      </td><td>2024-03-22</td><td style="text-align: right;">  2024</td><td style="text-align: right;">        689.187 </td><td>USD       </td></tr>\n<tr><td style="text-align: right;">16</td><td>O       </td><td>2023-11-30</td><td style="text-align: right;">  2023</td><td style="text-align: right;">         54.0464</td><td>USD       </td></tr>\n<tr><td style="text-align: right;">17</td><td>O       </td><td>2023-12-29</td><td style="text-align: right;">  2023</td><td style="text-align: right;">         54.6277</td><td>USD       </td></tr>\n<tr><td style="text-align: right;">18</td><td>O       </td><td>2024-01-31</td><td style="text-align: right;">  2024</td><td style="text-align: right;">         56.0777</td><td>USD       </td></tr>\n<t ...

# %%
# tabulate.tabulate(
#     dividends.groupby(by="ticker")["total_gain_czk"].agg("sum"),
#     tablefmt="html",
#     headers="keys",
# )
dividends.groupby(by="ticker")["total_gain_czk"].agg("sum")
# Out:
# ticker
# BAC          244.081166
# CEZ.PR      1740.000000
# KOMB.PR     7398.640000
# META          23.480433
# MO           908.917184
# MONET.PR    6840.000000
# O            336.365947
# WPC         1278.287644
# Name: total_gain_czk, dtype: float64

# %%
# tabulate.tabulate(
#     dividends.groupby(by="year")["total_gain_czk"].agg("sum"),
#     tablefmt="html",
#     headers="keys",
# )
dividends.groupby(by="year")["total_gain_czk"].agg("sum")
# Out:
# year
# 2022     805.000000
# 2023    8277.591016
# 2024    9687.181359
# Name: total_gain_czk, dtype: float64

# %%
dividends.groupby(["year","currency"])["total_gain_czk"].agg("sum")
# Out:
# year  currency
# 2022  CZK          805.000000
# 2023  CZK         6936.380000
#       USD         1341.211016
# 2024  CZK         8237.260000
#       USD         1449.921359
# Name: total_gain_czk, dtype: float64

# %%
predicted_dividends = get_dividend_prediction(trades, datetime.now().year)
predicted_dividends
# Out:
# WARNING: ussing older currency rate for USD. 2024-05-16 instead 2024-06-01
# Exchange rate called
# WARNING: ussing older currency rate for USD. 2024-05-16 instead 2024-08-31
# Exchange rate called
# WARNING: ussing older currency rate for USD. 2024-05-16 instead 2024-11-30
# Exchange rate called
# WARNING: ussing older currency rate for USD. 2024-05-16 instead 2024-06-29
# Exchange rate called
# WARNING: ussing older currency rate for USD. 2024-05-16 instead 2024-09-28
# Exchange rate called
# WARNING: ussing older currency rate for USD. 2024-05-16 instead 2024-12-28
# Exchange rate called
# WARNING: ussing older currency rate for USD. 2024-05-16 instead 2024-06-14
# Exchange rate called
# WARNING: ussing older currency rate for USD. 2024-05-16 instead 2024-09-14
# Exchange rate called
# WARNING: ussing older currency rate for USD. 2024-05-16 instead 2024-12-20
# Exchange rate called
# WARNING: ussing older currency rate for USD. 2024-05-16 instead 2024-05-31
# Exchange rate called
# WARNING: ussing older currency rate for USD. 2024-05-16 instead 2024-06-30
# Exchange rate called
# WARNING: ussing older currency rate for USD. 2024-05-16 instead 2024-07-31
# Exchange rate called
# WARNING: ussing older currency rate for USD. 2024-05-16 instead 2024-09-29
# Exchange rate called
# WARNING: ussing older currency rate for USD. 2024-05-16 instead 2024-10-31
# Exchange rate called
# WARNING: ussing older currency rate for USD. 2024-05-16 instead 2024-12-29
# Exchange rate called
# WARNING: ussing older currency rate for USD. 2024-05-16 instead 2024-06-21
# Exchange rate called
# WARNING: ussing older currency rate for USD. 2024-05-16 instead 2024-09-20
# Exchange rate called
#       ticker        date  year  total_gain_czk currency
# 0   MONET.PR  2024-04-28  2024     2840.000000      CZK
# 1     CEZ.PR  2024-06-29  2024    13340.000000      CZK
# 2    KOMB.PR  2024-04-28  2024     3685.620000      CZK
# 3        BAC  2024-03-02  2024       77.313327      USD
# 4        BAC  2024-06-01  2024       75.041137      USD
# 5        BAC  2024-08-31  2024       81.863059      USD
# 6        BAC  2024-11-30  2024       81.863059      USD
# 7        WPC  2024-03-30  2024      513.686912      USD
# 8        WPC  2024-06-29  2024      690.455257      USD
# 9        WPC  2024-09-28  2024      691.747124      USD
# 10       WPC  2024-12-28  2024      567.129082      USD
# 11        MO  2024-03-23  2024      661.057193      USD
# 12        MO  2024-06-14  2024      641.260629      USD
# 13        MO  2024-09-14  2024      668.548316      USD
# 14        MO  2024-12-20  2024      668.548316      USD
# 15         O  2024-01-31  2024       54.332067      USD
# 16         O  2024-02-28  2024       56.823853      USD
# 17         O  2024-03-31  2024       56.702768      USD
# 18         O  2024-04-28  2024       56.897321      USD
# 19         O  2024-05-31  2024       55.087017      USD
# 20         O  2024-06-30  2024       55.303044      USD
# 21         O  2024-07-31  2024       55.303044      USD
# 22         O  2024-08-31  2024       55.303044      USD
# 23         O  2024-09-29  2024       55.303044      USD
# 24         O  2024-10-31  2024       55.303044      USD
# 25         O  2024-11-30  2024       55.303044      USD
# 26         O  2024-12-29  2024       55.519072      USD
# 27      VICI  2024-06-21  2024      283.791938      USD
# 28      VICI  2024-09-20  2024      301.983729      USD
# 29      VICI  2024-12-20  2024      301.983729      USD

# %%
predicted_dividends.groupby(by="ticker")["total_gain_czk"].agg("sum")
# Out:
# ticker
# BAC           316.080582
# CEZ.PR      13340.000000
# KOMB.PR      3685.620000
# MO           2639.414454
# MONET.PR     2840.000000
# O             667.180363
# VICI          887.759396
# WPC          2463.018375
# Name: total_gain_czk, dtype: float64

# %%
predicted_dividends["total_gain_czk"].sum()
# Out:
# 26839.073171248954

# %%
## ToDO
# casovy vyvoj ETF a Bitcoinu
# procentualni dividendy per akcii v pomeru za nakupku a v pomeru k aktualni cene
# vyresit co s prodeji!!!

# %% [markdown]
# # Watchlist

# %%
watchlist = read_watchlist()
watchlist
# Out:
#                               name  ticker  price_limit currency
# 0               Berkshire Hathaway   BRK-B        400.0      USD
# 1                   W.P. Carey Inc     WPC         90.0      USD
# 2              VICI Properties Inc    VICI         38.0      USD
# 3              Realty Income Corp.       O         68.0      USD
# 4   National Retail Properties Inc     NNN         47.0      USD
# 5                  Bank of America     BAC         33.0      USD
# 6                Altria Group Inc.      MO         45.0      USD
# 7                   Blink Charging    BLNK          2.3      USD
# 8                              CEZ  CEZ.PR        850.0      CZK
# 9                      Match Group    MTCH         49.0      USD
# 10                 Lockheed Martin     LMT        430.0      USD
# 11            Rolls-Royce Holdings   RYCEY          5.0      USD

# %%
# Aktuální datum
current_date = datetime.now().date()
n_days = 60
start_date = current_date - timedelta(days=n_days)
# Vytvoření seznamu posledních třiceti dnů
time_evol = pd.DataFrame(columns=["date", "ticker", "ratio"])
for ticker in watchlist["ticker"]:
    currency = watchlist[watchlist["ticker"] == ticker].iloc[0]["currency"]
    price_limit = watchlist[watchlist["ticker"] == ticker].iloc[0]["price_limit"]
    stock = yf.Ticker(ticker)
    stock_history = stock.history(
        start=start_date.strftime("%Y-%m-%d"), end=current_date.strftime("%Y-%m-%d")
    )["Close"].reset_index()
    stock_history["Date"] = stock_history["Date"].dt.strftime("%Y-%m-%d")
    stock_history["ratio"] = stock_history["Close"] / price_limit
    for id,row in stock_history.iterrows():
        time_evol.loc[len(time_evol)] = [
            row["Date"],
            ticker,
            row["ratio"]
        ]

# %%
fig = px.line(
    time_evol,
    x="date",
    y="ratio",
    color="ticker",
    title="Buy ratio",
    template="plotly_dark",
    width=1200,
    height=800,
)

# showing the plot
fig.show()

# %%
current_date = datetime.now().date()
n_days = 60
start_date = current_date - timedelta(days=n_days)
# Vytvoření seznamu posledních třiceti dnů
time_evol = pd.DataFrame(columns=["date", "ticker", "ratio"])
for ticker in summary["ticker"]:
    currency = summary[summary["ticker"] == ticker].iloc[0]["currency"]
    price_limit = summary[summary["ticker"] == ticker].iloc[0][
        "mean_price"
    ] / get_exchange_rate(currency, current_date)
    stock = yf.Ticker(ticker)
    stock_history = stock.history(
        start=start_date.strftime("%Y-%m-%d"), end=current_date.strftime("%Y-%m-%d")
    )["Close"].reset_index()
    stock_history["Date"] = stock_history["Date"].dt.strftime("%Y-%m-%d")
    stock_history["ratio"] = stock_history["Close"] / price_limit
    if stock_history["ratio"].min() < 1.2:
        for id, row in stock_history.iterrows():
            time_evol.loc[len(time_evol)] = [row["Date"], ticker, row["ratio"]]

# %%
fig = px.line(
    time_evol,
    x="date",
    y="ratio",
    color="ticker",
    title="Buy ratio",
    template="plotly_dark",
    width=1200,
    height=800,
)

# showing the plot
fig.show()

# %%
save_exchange_rates()
