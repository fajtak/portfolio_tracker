# %%
from matplotlib import pyplot as plt
from show_portfolio import *
import tabulate
from IPython.display import display, HTML
# import  datetime
from datetime import timedelta, datetime

# %%
#trades_filter = ["BTC-USD", "IWDA.AS","VUAA.DE","CEZ.PR","MONET.PR","KOMB.PR"]
trades_filter = ["BTC-USD", "IWDA.AS","VUAA.DE"]
#trades_filter = ["BTC-USD"]
trades = read_trades(filter=trades_filter)
calculate_columns(trades)
# Out:
# WARNING: ussing older currency rate for USD. 2024-05-17 instead 2024-05-18
# Exchange rate called

# %% [markdown]
# # Trades

# %% [markdown]
# ### Akcie

# %%
tabulate.tabulate(
    trades[trades.type == "Akcie"].sort_values("date").reset_index(drop=True),
    tablefmt="html",
    headers="keys",
)
# Out:
# '<table>\n<thead>\n<tr><th style="text-align: right;">  </th><th>name           </th><th>ticker  </th><th>type  </th><th>tradeType  </th><th>date      </th><th style="text-align: right;">   units</th><th style="text-align: right;">  price</th><th style="text-align: right;">  fees</th><th>currency  </th><th style="text-align: right;">  note</th><th style="text-align: right;">  total_price</th><th style="text-align: right;">  current_price</th><th style="text-align: right;">  current_total_price</th><th style="text-align: right;">     profit</th><th style="text-align: right;">   change</th></tr>\n</thead>\n<tbody>\n<tr><td style="text-align: right;"> 0</td><td>Moneta         </td><td>MONET.PR</td><td>Akcie </td><td>Buy        </td><td>2022-04-27</td><td style="text-align: right;">106     </td><td style="text-align: right;">  94   </td><td style="text-align: right;">     0</td><td>CZK       </td><td style="text-align: right;">   nan</td><td style="text-align: right;">     9964    </td><td style="text-align: right;">         96.1  </td><td style="text-align: right;">            10186.6  </td><td style="text-align: right;">  222.6    </td><td style="text-align: right;">  2.23404</td></tr>\n<tr><td style="text-align: right;"> 1</td><td>Moneta         </td><td>MONET.PR</td><td>Akcie </td><td>Buy        </td><td>2022-04-28</td><td style="text-align: right;">  9     </td><td style="text-align: right;">  93.9 </td><td style="text-align: right;">     0</td><td>CZK       </td><td style="text-align: right;">   nan</td><td style="text-align: right;">      845.1  </td><td style="text-align: right;">         96.1  </td><td style="text-align: right;">              864.9  </td><td style="text-align: right;">   19.8    </td><td style="text-align: right;">  2.34292</td></tr>\n<tr><td style="text-align: right;"> 2</td><td>FB             </td><td>META    </td><td>Akcie </td><td>Buy        </td><td>2022-06-21</td><td style="text-align: right;">  2     </td><td style="text-align: right;"> 156.87</td><td style="text-align: right;">     0</td><td>USD       </td><td style="text-align: right;">   nan</td><td style="text-align: right;">     7342.41 </td><td style="text-align: right;">      10758.5  </td><td style="text-align: right;">            21517.1  </td><td style="text-align: right;">14174.7    </td><td style="text-align: right;">193.052  </td></tr>\n<tr><td style="text-align: right;"> 3</td><td>Palantir       </td><td>PLTR    </td><td>Akcie </td><td>Buy        </td><td>2022-08-04</td><td style="text-align: right;"> 11     </td><td style="text-align: right;">  11.32</td><td style="text-align: right;">     0</td><td>USD       </td><td style="text-align: right;">   nan</td><td style="text-align: right;">     3015.95 </td><td style="text-align: right;">        496.081</td><td style="text-align: right;">             5456.9  </td><td style="text-align: right;"> 2440.95   </td><td style="text-align: right;"> 80.9346 </td></tr>\n<tr><td style="text-align: right;"> 4</td><td>CEZ            </td><td>CEZ.PR  </td><td>Akcie </td><td>Buy        </td><td>2022-10-27</td><td style="text-align: right;"> 12     </td><td style="text-align: right;"> 815   </td><td style="text-align: right;">     0</td><td>CZK       </td><td style="text-align: right;">   nan</td><td style="text-align: right;">     9780    </td><td style="text-align: right;">        914    </td><td style="text-align: right;">            10968    </td><td style="text-align: right;"> 1188      </td><td style="text-align: right;"> 12.1472 </td></tr>\n<tr><td style="text-align: right;"> 5</td><td>Komercni banka </td><td>KOMB.PR </td><td>Akcie </td><td>Buy        </td><td>2023-02-27</td><td style="text-align: right;"> 13     </td><td style="text-align: right;"> 749   </td><td style="text-align: right;">     0</td><td>CZK       </td><td style="text-align: right;">   nan</td><td style="text-align: right;">     9737    </td><td style="text-align: right;">        784.5  </td><td style="text-align: right;">       ...

# %% [markdown]
# ### ETF

# %%
tabulate.tabulate(
    trades[trades.type == "ETF"].sort_values("date").reset_index(drop=True),
    tablefmt="html",
    headers="keys",
)
# Out:
# '<table>\n<thead>\n<tr></tr>\n</thead>\n<tbody>\n</tbody>\n</table>'

# %% [markdown]
# ### Krypto

# %%
tabulate.tabulate(
    trades[trades.type == "Krypto"].sort_values("date").reset_index(drop=True),
    tablefmt="html",
    headers="keys",
)
# Out:
# '<table>\n<thead>\n<tr></tr>\n</thead>\n<tbody>\n</tbody>\n</table>'

# %% [markdown]
# # Investice

# %%
first_date = datetime.fromisoformat(trades["date"].sort_values().iloc[0]).date()
today_date = datetime.now().date()
n_months = round((today_date-first_date).days/30)
total_invested_czk = trades["total_price"].sum()
print("Pocet mesicu od prvni investice:",n_months)
print("Celkem investovano:",f"{total_invested_czk:.2f}")
print("Prumerna investovana castka:",f"{total_invested_czk/n_months:.2f}")
# Out:
# Pocet mesicu od prvni investice: 25
# Celkem investovano: 316318.32
# Prumerna investovana castka: 12652.73

# %%
first_year = first_date.year
last_year = today_date.year
dates = []
for year in range(first_year,last_year+1):
    dates.extend([f"{str(year)[-2:]}/{x:0>2}" for x in range(1,13)])
values = [0]*len(dates)
all_trades_small = pd.DataFrame(index=dates,data=values,columns=["total_price"])

# %%
trades_small = trades.loc[:,["date","total_price"]]
trades_small["date"] = trades_small["date"].apply(lambda x: x.split("-")[0][-2:] + "/" + x.split("-")[1])
trades_small = trades_small.groupby("date").agg("sum")
for index,values in trades_small.iterrows():
	# print(index,values["total_price"])
	all_trades_small.loc[index] = values["total_price"]
# trades_small
all_trades_small.reset_index(names="date",inplace=True)

# %%
fig = px.bar(
    all_trades_small,
    x="date",
    y="total_price",
    title="Historical investments",
    template="plotly_dark",
    width=1200,
    height=800,
)

# showing the plot
fig.show()

# %%
all_trades_small[["year","month"]] = all_trades_small["date"].str.split("/",expand=True)
pivot_trades = all_trades_small.pivot(index="year",columns="month",values="total_price")
pivot_trades["celkem"] = pivot_trades.sum(axis=1)
pivot_trades
# Out:
# month          01       02            03            04           05  \
# year
# 22         0.0000      0.0      0.000000  10809.100000      0.00000
# 23         0.0000   9737.0      0.000000  51332.153937  14553.00000
# 24     19687.5045  19040.0  20620.530226  20613.734170  20078.39913
#
# month            06       07            08   09      10            11  \
# year
# 22      7342.408152      0.0   3015.949985  0.0  9780.0      0.000000
# 23     28519.075367  16020.0  10149.374405  0.0     0.0  20357.278017
# 24         0.000000      0.0      0.000000  0.0     0.0      0.000000
#
# month            12         celkem
# year
# 22         0.000000   30947.458137
# 23     34662.812435  185330.694161
# 24         0.000000  100040.168025

# %% [markdown]
# # Prehled

# %%
summary = get_summary(trades)

# %%
get_overview(summary)
# Out:
# 	<div style="display:flex; justify-content: space-between;">
#
# 		<div style="width: 350px; background-color:#f2f2f2; padding:20px; border-radius: 10px;">
# 			<h2>Celková hodnota portfolia</h2>
# 			<p style="font-size:18px; color:#008080;">376041.90 Kc</p>
# 		</div>
#
# 		<div style="width: 350px; background-color:#f2f2f2; padding:20px; border-radius: 10px;">
# 			<h2>Investováno</h2>
><td style="text-align: right;"> 15.0133 </td></tr>\n<tr><td style="text-align: right;"> 7</td><td>MONET.PR</td><td style="text-align: right;">355     </td><td style="text-align: right;">     31425.1 </td><td>CZK       </td><td>Akcie </td><td style="text-align: right;">     88.5214</td><td style="text-align: right;">         96.1  </td><td style="text-align: right;">              34115.5</td><td style="text-align: right;"> 2690.4  </td><td style="text-align: right;">  8.56131</td></tr>\n<tr><td sty ...

# %%
show_portfolio_breakdown(summary)
show_portfolio_growth(summary)

# %% [markdown]
# # Casovy vyvoj

# %%
def get_units(ticker: str, date_to: str) -> float:
    return trades[(trades.ticker == ticker) & (trades.date < date_to)]["units"].sum()


def get_total_price(ticker: str, date_to: str) -> float:
    return trades[(trades.ticker == ticker) & (trades.date < date_to)]["total_price"].sum()

# %%
# Aktuální datum
current_date = datetime.now().date()
n_days = 550
# Vytvoření seznamu posledních třiceti dnů
last_thirty_days = [
    (current_date - timedelta(days=i)).strftime("%Y-%m-%d") for i in range(n_days)
]
safety_range = (current_date - timedelta(days=n_days + 10)).strftime("%Y-%m-%d")
last_thirty_days = sorted(last_thirty_days)
time_evol = pd.DataFrame(columns=["date", "ticker", "value","total_price"])
for ticker in summary["ticker"].unique():
    # for ticker in ["CEZ.PR"]:
    currency = summary[summary["ticker"] == ticker].iloc[0]["currency"]
    stock = yf.Ticker(ticker)
    history = stock.history(start=safety_range, end=last_thirty_days[-1])[
        "Close"
    ].reset_index()
    history["Date"] = history["Date"].dt.strftime("%Y-%m-%d")
    # print(history)
    for date in last_thirty_days:
        # print(date)
        if date in history["Date"].values:
            price = float(history[history["Date"] == date]["Close"])
            # print("Found:",price)
        else:
            price = history[history["Date"] < date].iloc[-1]["Close"]
            # print("Not found",price)
        time_evol.loc[len(time_evol)] = [date,ticker,price * get_exchange_rate(currency, date) * get_units(ticker, date), get_total_price(ticker,date)]
        # print(index, price, get_exchange_rate(currency, index))
# print(time_evol)
time_evol["gain"] = time_evol["value"]/time_evol["total_price"]*100-100

# %%
print(time_evol)
# Out:
#             date ticker         value   total_price      gain
# 0     2022-11-16    BAC      0.000000      0.000000       NaN
# 1     2022-11-17    BAC      0.000000      0.000000       NaN
# 2     2022-11-18    BAC      0.000000      0.000000       NaN
# 3     2022-11-19    BAC      0.000000      0.000000       NaN
# 4     2022-11-20    BAC      0.000000      0.000000       NaN
# ...          ...    ...           ...           ...       ...
# 7145  2024-05-14    WPC  39457.633758  41002.857495 -3.768576
# 7146  2024-05-15    WPC  39431.487682  41002.857495 -3.832342
# 7147  2024-05-16    WPC  39276.987064  41002.857495 -4.209147
# 7148  2024-05-17    WPC  39741.002967  41002.857495 -3.077479
# 7149  2024-05-18    WPC  39741.002967  41002.857495 -3.077479
#
# [7150 rows x 5 columns]

# %%
fig = px.line(
    time_evol,
    x="date",
    y="value",
    color="ticker",
    title="Time evolution",
    template="plotly_dark",
    width=1200,
    height=800,
)

# showing the plot
fig.show()

# %%
fig = px.line(
    time_evol,
    x="date",
    y="gain",
    color="ticker",
    title="Time evolution",
    template="plotly_dark",
    width=1200,
    height=800,
)

# showing the plot
fig.show()

# %%
print(time_evol)
# Out:
#             date ticker         value   total_price      gain
# 0     2022-11-16    BAC      0.000000      0.000000       NaN
# 1     2022-11-17    BAC      0.000000      0.000000       NaN
# 2     2022-11-18    BAC      0.000000      0.000000       NaN
# 3     2022-11-19    BAC      0.000000      0.000000       NaN
# 4     2022-11-20    BAC      0.000000      0.000000       NaN
# ...          ...    ...           ...           ...       ...
# 7145  2024-05-14    WPC  39457.633758  41002.857495 -3.768576
# 7146  2024-05-15    WPC  39431.487682  41002.857495 -3.832342
# 7147  2024-05-16    WPC  39276.987064  41002.857495 -4.209147
# 7148  2024-05-17    WPC  39741.002967  41002.857495 -3.077479
# 7149  2024-05-18    WPC  39741.002967  41002.857495 -3.077479
#
# [7150 rows x 5 columns]

# %%
time_evol_all = time_evol.groupby("date").agg({"value":"sum","total_price":"sum"}).reset_index()
time_evol_all["gainAbs"] = time_evol_all["value"] - time_evol_all["total_price"]
time_evol_all["gain"] = time_evol_all["value"]/time_evol_all["total_price"]*100-100
time_evol_all
# Out:
#            date          value    total_price       gainAbs       gain
# 0    2022-11-16   22551.098437   30947.458137  -8396.359700 -27.131016
# 1    2022-11-17   22432.378859   30947.458137  -8515.079278 -27.514632
# 2    2022-11-18   22470.416076   30947.458137  -8477.042060 -27.391723
# 3    2022-11-19   22470.416076   30947.458137  -8477.042060 -27.391723
# 4    2022-11-20   22470.416076   30947.458137  -8477.042060 -27.391723
# ..          ...            ...            ...           ...        ...
# 545  2024-05-14  374710.051773  316318.320323  58391.731450  18.459801
# 546  2024-05-15  378202.895921  316318.320323  61884.575597  19.564019
# 547  2024-05-16  375297.300717  316318.320323  58978.980393  18.645452
# 548  2024-05-17  376041.903001  316318.320323  59723.582678  18.880848
# 549  2024-05-18  376041.903001  316318.320323  59723.582678  18.880848
#
# [550 rows x 5 columns]

# %%
time_evol_all.columns[1:-1]
# Out:
# Index(['value', 'total_price', 'gainAbs'], dtype='object')

# %%
fig = px.line(
    time_evol_all,
    x="date",
    # y=["value","total_gain"],
    y=time_evol_all.columns[1:-2],
    title="Time evolution",
    template="plotly_dark",
    width=1200,
    height=800,
)

# showing the plot
fig.show()

# %%
fig = px.line(
    time_evol_all,
    x="date",
    y="gainAbs",
    title="Time evolution",
    template="plotly_dark",
    width=1200,
    height=800,
)

# showing the plot
fig.show()

# %%
fig = px.line(
    time_evol_all,
    x="date",
    y="gain",
    title="Time evolution",
    template="plotly_dark",
    width=1200,
    height=800,
)

# showing the plot
fig.show()

# %% [markdown]
# # Porovnani s S&P500

# %%
def get_next_day(str_date: str, plus_n: int = 1) -> str:
    res = datetime.fromisoformat(str_date) + timedelta(days=plus_n)
    return str(res.date())

stock_name = "S&P"
stock_ticker = "SPY"

SAP_trades = read_trades(filter=trades_filter)
SAP_trades["date"] = SAP_trades["date"].apply(transform_date)

SAP_stock = yf.Ticker(stock_ticker)
# SAP_stock = yf.Ticker("SPY")
SAP_history = SAP_stock.history(start=SAP_trades["date"].min(), end=get_next_day(SAP_trades["date"].max()))["Close"]

SAP_trades = SAP_trades[SAP_trades["type"] == "Akcie"]
# SAP_trades["name"] = stock_name
SAP_trades["ticker"] = stock_ticker
SAP_trades["total_price"] = SAP_trades.apply(lambda x: x["units"]*x["price"]*get_exchange_rate(x["currency"],x["date"]),axis=1)
SAP_trades["date"]
SAP_trades["price"] = SAP_trades["date"].apply(lambda x: SAP_history[x])
SAP_trades["units"] = SAP_trades.apply(lambda x: x["total_price"]/get_exchange_rate("USD",x["date"])/x["price"],axis=1)
# Crowdstrike      10811.354194
# FB               11145.495477
# Google            4539.727843
# Komercni banka  -12427.788956
# Match              432.932277
# Moneta           -8441.037035
# Palantir          1729.136732
# Realty           -1508.681661
# VICI               752.536631
# WP Carey         -8100.903564

# %%
z = time_evol_all[time_evol_all.date == "2023-01-01"]
a = time_evol_all[time_evol_all.date == "2024-01-01"]
b = time_evol_all[time_evol_all.date == "2024-02-01"]
c = time_evol_all[time_evol_all.date == "2024-03-01"]
d = time_evol_all[time_evol_all.date == "2024-04-01"]
e = time_evol_all[time_evol_all.date == "2024-05-01"]

print((a["gainAbs"].iloc[0]-z["gainAbs"].iloc[0])/z["value"].iloc[0]*100)
print((b["gainAbs"].iloc[0]-a["gainAbs"].iloc[0])/a["value"].iloc[0]*100)
print((c["gainAbs"].iloc[0]-b["gainAbs"].iloc[0])/b["value"].iloc[0]*100)
print((d["gainAbs"].iloc[0]-c["gainAbs"].iloc[0])/c["value"].iloc[0]*100)
print((e["gainAbs"].iloc[0]-d["gainAbs"].iloc[0])/d["value"].iloc[0]*100)
print((e["gainAbs"].iloc[0]-a["gainAbs"].iloc[0])/a["value"].iloc[0]*100)
# Out:
# 133.4435910349833
# 3.2947983748139413
# 2.2897096729777
# 3.325149987459445
# 0.7023386952802687
# 10.860512554705625

# %%
# Aktuální datum
current_date = datetime.now().date()
n_days = 550
# Vytvoření seznamu posledních třiceti dnů
last_thirty_days = [
    (current_date - timedelta(days=i)).strftime("%Y-%m-%d") for i in range(n_days)
]
safety_range = (current_date - timedelta(days=n_days + 10)).strftime("%Y-%m-%d")
last_thirty_days = sorted(last_thirty_days)
time_evol = pd.DataFrame(columns=["date", "ticker", "valueUSD", "value"])
for ticker in ["^GSPC"]:
    # for ticker in ["CEZ.PR"]:
    currency = "USD"
    stock = yf.Ticker(ticker)
    history = stock.history(start=safety_range, end=last_thirty_days[-1])[
        "Close"
    ].reset_index()
    history["Date"] = history["Date"].dt.strftime("%Y-%m-%d")
    # print(history)
    for date in last_thirty_days:
        # print(date)
        if date in history["Date"].values:
            price = float(history[history["Date"] == date]["Close"])
            # print("Found:",price)
        else:
            price = history[history["Date"] < date].iloc[-1]["Close"]
            # print("Not found",price)
        time_evol.loc[len(time_evol)] = [date,ticker,price,price * get_exchange_rate(currency, date)]
        #time_evol.loc[len(time_evol)] = [date,ticker,price]
        # print(index, price, get_exchange_rate(currency, index))
# print(time_evol)

z = time_evol[time_evol.date == "2023-01-01"]
a = time_evol[time_evol.date == "2024-01-01"]
b = time_evol[time_evol.date == "2024-02-01"]
c = time_evol[time_evol.date == "2024-03-01"]
d = time_evol[time_evol.date == "2024-04-01"]
e = time_evol[time_evol.date == "2024-05-01"]

#print(z)
#print(a)
#print(b)
#print(c)
#print(d)

column = "valueUSD"
print((a[column].iloc[0]-z[column].iloc[0])/z[column].iloc[0]*100)
print((b[column].iloc[0]-a[column].iloc[0])/a[column].iloc[0]*100)
print((c[column].iloc[0]-b[column].iloc[0])/b[column].iloc[0]*100)
print((d[column].iloc[0]-c[column].iloc[0])/c[column].iloc[0]*100)
print((e[column].iloc[0]-d[column].iloc[0])/d[column].iloc[0]*100)
print((e[column].iloc[0]-a[column].iloc[0])/a[column].iloc[0]*100)
# Out:
# 24.2305007976299
# 2.8587991825246
# 4.706098611676874
# 2.076859612536761
# -4.2980504860632145
# 5.211088330665605

# %% [markdown]
# # Dividendy

# %%
dividends = get_dividends(trades)
tabulate.tabulate(
    dividends,
    tablefmt="html",
    headers="keys",
)
# Out:
# '<table>\n<thead>\n<tr><th style="text-align: right;">  </th><th>ticker  </th><th>date      </th><th style="text-align: right;">  year</th><th style="text-align: right;">  total_gain_czk</th><th>currency  </th></tr>\n</thead>\n<tbody>\n<tr><td style="text-align: right;"> 0</td><td>MONET.PR</td><td>2022-04-29</td><td style="text-align: right;">  2022</td><td style="text-align: right;">        805     </td><td>CZK       </td></tr>\n<tr><td style="text-align: right;"> 1</td><td>MONET.PR</td><td>2023-04-28</td><td style="text-align: right;">  2023</td><td style="text-align: right;">       2840     </td><td>CZK       </td></tr>\n<tr><td style="text-align: right;"> 2</td><td>MONET.PR</td><td>2024-04-26</td><td style="text-align: right;">  2024</td><td style="text-align: right;">       3195     </td><td>CZK       </td></tr>\n<tr><td style="text-align: right;"> 3</td><td>META    </td><td>2024-02-21</td><td style="text-align: right;">  2024</td><td style="text-align: right;">         23.4804</td><td>USD       </td></tr>\n<tr><td style="text-align: right;"> 4</td><td>CEZ.PR  </td><td>2023-06-29</td><td style="text-align: right;">  2023</td><td style="text-align: right;">       1740     </td><td>CZK       </td></tr>\n<tr><td style="text-align: right;"> 5</td><td>KOMB.PR </td><td>2023-04-28</td><td style="text-align: right;">  2023</td><td style="text-align: right;">       2356.38  </td><td>CZK       </td></tr>\n<tr><td style="text-align: right;"> 6</td><td>KOMB.PR </td><td>2024-05-03</td><td style="text-align: right;">  2024</td><td style="text-align: right;">       5042.26  </td><td>CZK       </td></tr>\n<tr><td style="text-align: right;"> 7</td><td>BAC     </td><td>2023-08-31</td><td style="text-align: right;">  2023</td><td style="text-align: right;">         79.7379</td><td>USD       </td></tr>\n<tr><td style="text-align: right;"> 8</td><td>BAC     </td><td>2023-11-30</td><td style="text-align: right;">  2023</td><td style="text-align: right;">         80.0029</td><td>USD       </td></tr>\n<tr><td style="text-align: right;"> 9</td><td>BAC     </td><td>2024-02-29</td><td style="text-align: right;">  2024</td><td style="text-align: right;">         84.3403</td><td>USD       </td></tr>\n<tr><td style="text-align: right;">10</td><td>WPC     </td><td>2023-06-29</td><td style="text-align: right;">  2023</td><td style="text-align: right;">        136.037 </td><td>USD       </td></tr>\n<tr><td style="text-align: right;">11</td><td>WPC     </td><td>2023-09-28</td><td style="text-align: right;">  2023</td><td style="text-align: right;">        315.432 </td><td>USD       </td></tr>\n<tr><td style="text-align: right;">12</td><td>WPC     </td><td>2023-12-28</td><td style="text-align: right;">  2023</td><td style="text-align: right;">        401.597 </td><td>USD       </td></tr>\n<tr><td style="text-align: right;">13</td><td>WPC     </td><td>2024-03-27</td><td style="text-align: right;">  2024</td><td style="text-align: right;">        425.222 </td><td>USD       </td></tr>\n<tr><td style="text-align: right;">14</td><td>MO      </td><td>2023-12-20</td><td style="text-align: right;">  2023</td><td style="text-align: right;">        219.73  </td><td>USD       </td></tr>\n<tr><td style="text-align: right;">15</td><td>MO      </td><td>2024-03-22</td><td style="text-align: right;">  2024</td><td style="text-align: right;">        689.187 </td><td>USD       </td></tr>\n<tr><td style="text-align: right;">16</td><td>O       </td><td>2023-11-30</td><td style="text-align: right;">  2023</td><td style="text-align: right;">         54.0464</td><td>USD       </td></tr>\n<tr><td style="text-align: right;">17</td><td>O       </td><td>2023-12-29</td><td style="text-align: right;">  2023</td><td style="text-align: right;">         54.6277</td><td>USD       </td></tr>\n<tr><td style="text-align: right;">18</td><td>O       </td><td>2024-01-31</td><td style="text-align: right;">  2024</td><td style="text-align: right;">         56.0777</td><td>USD       </td></tr>\n<t ...

# %%
# tabulate.tabulate(
#     dividends.groupby(by="ticker")["total_gain_czk"].agg("sum"),
#     tablefmt="html",
#     headers="keys",
# )
dividends.groupby(by="ticker")["total_gain_czk"].agg("sum")
# Out:
# ticker
# BAC          244.081166
# CEZ.PR      1740.000000
# KOMB.PR     7398.640000
# META          23.480433
# MO           908.917184
# MONET.PR    6840.000000
# O            336.365947
# WPC         1278.287644
# Name: total_gain_czk, dtype: float64

# %%
# tabulate.tabulate(
#     dividends.groupby(by="year")["total_gain_czk"].agg("sum"),
#     tablefmt="html",
#     headers="keys",
# )
dividends.groupby(by="year")["total_gain_czk"].agg("sum")
# Out:
# year
# 2022     805.000000
# 2023    8277.591016
# 2024    9687.181359
# Name: total_gain_czk, dtype: float64

# %%
dividends.groupby(["year","currency"])["total_gain_czk"].agg("sum")
# Out:
# year  currency
# 2022  CZK          805.000000
# 2023  CZK         6936.380000
#       USD         1341.211016
# 2024  CZK         8237.260000
#       USD         1449.921359
# Name: total_gain_czk, dtype: float64

# %%
predicted_dividends = get_dividend_prediction(trades, datetime.now().year)
predicted_dividends
# Out:
# WARNING: ussing older currency rate for USD. 2024-05-17 instead 2024-06-01
# Exchange rate called
# WARNING: ussing older currency rate for USD. 2024-05-17 instead 2024-08-31
# Exchange rate called
# WARNING: ussing older currency rate for USD. 2024-05-17 instead 2024-11-30
# Exchange rate called
# WARNING: ussing older currency rate for USD. 2024-05-17 instead 2024-06-29
# Exchange rate called
# WARNING: ussing older currency rate for USD. 2024-05-17 instead 2024-09-28
# Exchange rate called
# WARNING: ussing older currency rate for USD. 2024-05-17 instead 2024-12-28
# Exchange rate called
# WARNING: ussing older currency rate for USD. 2024-05-17 instead 2024-06-14
# Exchange rate called
# WARNING: ussing older currency rate for USD. 2024-05-17 instead 2024-09-14
# Exchange rate called
# WARNING: ussing older currency rate for USD. 2024-05-17 instead 2024-12-20
# Exchange rate called
# WARNING: ussing older currency rate for USD. 2024-05-17 instead 2024-05-31
# Exchange rate called
# WARNING: ussing older currency rate for USD. 2024-05-17 instead 2024-06-30
# Exchange rate called
# WARNING: ussing older currency rate for USD. 2024-05-17 instead 2024-07-31
# Exchange rate called
# WARNING: ussing older currency rate for USD. 2024-05-17 instead 2024-09-29
# Exchange rate called
# WARNING: ussing older currency rate for USD. 2024-05-17 instead 2024-10-31
# Exchange rate called
# WARNING: ussing older currency rate for USD. 2024-05-17 instead 2024-12-29
# Exchange rate called
# WARNING: ussing older currency rate for USD. 2024-05-17 instead 2024-06-21
# Exchange rate called
# WARNING: ussing older currency rate for USD. 2024-05-17 instead 2024-09-20
# Exchange rate called
#       ticker        date  year  total_gain_czk currency
# 0   MONET.PR  2024-04-28  2024     2840.000000      CZK
# 1     CEZ.PR  2024-06-29  2024    13340.000000      CZK
# 2    KOMB.PR  2024-04-28  2024     3685.620000      CZK
# 3        BAC  2024-03-02  2024       77.313327      USD
# 4        BAC  2024-06-01  2024       75.232940      USD
# 5        BAC  2024-08-31  2024       82.072298      USD
# 6        BAC  2024-11-30  2024       82.072298      USD
# 7        WPC  2024-03-30  2024      513.686912      USD
# 8        WPC  2024-06-29  2024      692.220035      USD
# 9        WPC  2024-09-28  2024      693.515204      USD
# 10       WPC  2024-12-28  2024      568.578643      USD
# 11        MO  2024-03-23  2024      661.057193      USD
# 12        MO  2024-06-14  2024      642.899668      USD
# 13        MO  2024-09-14  2024      670.257101      USD
# 14        MO  2024-12-20  2024      670.257101      USD
# 15         O  2024-01-31  2024       54.332067      USD
# 16         O  2024-02-28  2024       56.823853      USD
# 17         O  2024-03-31  2024       56.702768      USD
# 18         O  2024-04-28  2024       56.897321      USD
# 19         O  2024-05-31  2024       55.227817      USD
# 20         O  2024-06-30  2024       55.444397      USD
# 21         O  2024-07-31  2024       55.444397      USD
# 22         O  2024-08-31  2024       55.444397      USD
# 23         O  2024-09-29  2024       55.444397      USD
# 24         O  2024-10-31  2024       55.444397      USD
# 25         O  2024-11-30  2024       55.444397      USD
# 26         O  2024-12-29  2024       55.660977      USD
# 27      VICI  2024-06-21  2024      284.517300      USD
# 28      VICI  2024-09-20  2024      302.755588      USD
# 29      VICI  2024-12-20  2024      302.755588      USD

# %%
predicted_dividends.groupby(by="ticker")["total_gain_czk"].agg("sum")
# Out:
# ticker
# BAC           316.690863
# CEZ.PR      13340.000000
# KOMB.PR      3685.620000
# MO           2644.471062
# MONET.PR     2840.000000
# O             668.311184
# VICI          890.028477
# WPC          2468.000795
# Name: total_gain_czk, dtype: float64

# %%
predicted_dividends["total_gain_czk"].sum()
# Out:
# 26853.122379800192

# %%
## ToDO
# casovy vyvoj ETF a Bitcoinu
# procentualni dividendy per akcii v pomeru za nakupku a v pomeru k aktualni cene
# vyresit co s prodeji!!!

# %% [markdown]
# # Watchlist

# %%
watchlist = read_watchlist()
watchlist
# Out:
#                               name  ticker  price_limit currency
# 0               Berkshire Hathaway   BRK-B        400.0      USD
# 1                   W.P. Carey Inc     WPC         90.0      USD
# 2              VICI Properties Inc    VICI         38.0      USD
# 3              Realty Income Corp.       O         68.0      USD
# 4   National Retail Properties Inc     NNN         47.0      USD
# 5                  Bank of America     BAC         33.0      USD
# 6                Altria Group Inc.      MO         45.0      USD
# 7                   Blink Charging    BLNK          2.3      USD
# 8                              CEZ  CEZ.PR        850.0      CZK
# 9                      Match Group    MTCH         49.0      USD
# 10                 Lockheed Martin     LMT        430.0      USD
# 11            Rolls-Royce Holdings   RYCEY          5.0      USD

# %%
# Aktuální datum
current_date = datetime.now().date()
n_days = 60
start_date = current_date - timedelta(days=n_days)
# Vytvoření seznamu posledních třiceti dnů
time_evol = pd.DataFrame(columns=["date", "ticker", "ratio"])
for ticker in watchlist["ticker"]:
    currency = watchlist[watchlist["ticker"] == ticker].iloc[0]["currency"]
    price_limit = watchlist[watchlist["ticker"] == ticker].iloc[0]["price_limit"]
    stock = yf.Ticker(ticker)
    stock_history = stock.history(
        start=start_date.strftime("%Y-%m-%d"), end=current_date.strftime("%Y-%m-%d")
    )["Close"].reset_index()
    stock_history["Date"] = stock_history["Date"].dt.strftime("%Y-%m-%d")
    stock_history["ratio"] = stock_history["Close"] / price_limit
    for id,row in stock_history.iterrows():
        time_evol.loc[len(time_evol)] = [
            row["Date"],
            ticker,
            row["ratio"]
        ]

# %%
fig = px.line(
    time_evol,
    x="date",
    y="ratio",
    color="ticker",
    title="Buy ratio",
    template="plotly_dark",
    width=1200,
    height=800,
)

# showing the plot
fig.show()

# %%
current_date = datetime.now().date()
n_days = 60
start_date = current_date - timedelta(days=n_days)
# Vytvoření seznamu posledních třiceti dnů
time_evol = pd.DataFrame(columns=["date", "ticker", "ratio"])
for ticker in summary["ticker"]:
    currency = summary[summary["ticker"] == ticker].iloc[0]["currency"]
    price_limit = summary[summary["ticker"] == ticker].iloc[0][
        "mean_price"
    ] / get_exchange_rate(currency, current_date)
    stock = yf.Ticker(ticker)
    stock_history = stock.history(
        start=start_date.strftime("%Y-%m-%d"), end=current_date.strftime("%Y-%m-%d")
    )["Close"].reset_index()
    stock_history["Date"] = stock_history["Date"].dt.strftime("%Y-%m-%d")
    stock_history["ratio"] = stock_history["Close"] / price_limit
    if stock_history["ratio"].min() < 1.2:
        for id, row in stock_history.iterrows():
            time_evol.loc[len(time_evol)] = [row["Date"], ticker, row["ratio"]]

# %%
fig = px.line(
    time_evol,
    x="date",
    y="ratio",
    color="ticker",
    title="Buy ratio",
    template="plotly_dark",
    width=1200,
    height=800,
)

# showing the plot
fig.show()

# %%
save_exchange_rates()
